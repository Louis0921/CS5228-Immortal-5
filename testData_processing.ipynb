# %%
# Programmer: Lu Jianzhang
# Time: 2023/10/8

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df_test = pd.read_csv('test.csv')

# %%
# Null value handling
df_test[df_test.isnull().T.any()]
# Out:
# Empty DataFrame
# Columns: [rent_approval_date, town, block, street_name, flat_type, flat_model, floor_area_sqm, furnished, lease_commence_date, latitude, longitude, elevation, subzone, planning_area, region]
# Index: []

# %%
# Delete "elevation","furnished"
df_test = df_test.drop(['elevation','furnished'],axis = 1)
df_test.head()
# Out:
#   rent_approval_date         town block             street_name flat_type  \
# 0            2023-01      hougang   245       hougang street 22    5-room
# 1            2022-09    sembawang   316         sembawang vista    4-room
# 2            2023-07     clementi   708  Clementi West Street 2    4-room
# 3            2021-08  jurong east   351   Jurong East Street 31    3 room
# 4            2022-03  jurong east   305   jurong east street 32    5-room
#
#        flat_model  floor_area_sqm  lease_commence_date  latitude   longitude  \
# 0        improved           121.0                 1984  1.358411  103.891722
# 1         model a           100.0                 1999  1.446343  103.820817
# 2  new generation            91.0                 1980  1.305719  103.762168
# 3         model a            74.0                 1986  1.344832  103.730778
# 4        improved           121.0                 1983  1.345437  103.735241
#
#              subzone planning_area             region
# 0      lorong ah soo       hougang  north-east region
# 1  sembawang central     sembawang       north region
# 2      clementi west      clementi        west region
# 3         yuhua west   jurong east        west region
# 4         yuhua west   jurong east        west region

# %%
# Clean the "flat_type"
df = df_test.copy()
df.loc[df['flat_type']=='2 room','flat_type']='2-room'
df.loc[df['flat_type']=='3 room','flat_type']='3-room'
df.loc[df['flat_type']=='4 room','flat_type']='4-room'
df.loc[df['flat_type']=='5 room','flat_type']='5-room'
df['flat_type'].unique()
# Out:
# array(['5-room', '4-room', '3-room', 'executive', '2-room'], dtype=object)

# %%
# Clean the "town"
df['town'].unique()
# Out:
# array(['hougang', 'sembawang', 'clementi', 'jurong east', 'punggol',
#        'tampines', 'jurong west', 'marine parade', 'woodlands',
#        'toa payoh', 'sengkang', 'bedok', 'choa chu kang', 'geylang',
#        'bukit batok', 'bukit panjang', 'serangoon', 'yishun',
#        'ang mo kio', 'bukit merah', 'bishan', 'central', 'pasir ris',
#        'kallang/whampoa', 'bukit timah', 'queenstown'], dtype=object)

# %%
# Clean the "subzone"
df['subzone'].unique()
df['subzone'].value_counts()
# Out:
# tampines east          1198
# bedok north             783
# jurong west central     719
# woodlands east          694
# tampines west           607
#                        ...
# bencoolen                 6
# moulmein                  5
# swiss club                2
# ulu pandan                2
# frankel                   2
# Name: subzone, Length: 152, dtype: int64

# %%
# Encode "lease_commence_date"
df['lease_commence_date'] = df.apply(lambda x: int(x['rent_approval_date'][0:4])-x['lease_commence_date'],axis = 1)
df.head()
# Out:
#   rent_approval_date         town block             street_name flat_type  \
# 0            2023-01      hougang   245       hougang street 22    5-room
# 1            2022-09    sembawang   316         sembawang vista    4-room
# 2            2023-07     clementi   708  Clementi West Street 2    4-room
# 3            2021-08  jurong east   351   Jurong East Street 31    3-room
# 4            2022-03  jurong east   305   jurong east street 32    5-room
#
#        flat_model  floor_area_sqm  lease_commence_date  latitude   longitude  \
# 0        improved           121.0                   39  1.358411  103.891722
# 1         model a           100.0                   23  1.446343  103.820817
# 2  new generation            91.0                   43  1.305719  103.762168
# 3         model a            74.0                   35  1.344832  103.730778
# 4        improved           121.0                   39  1.345437  103.735241
#
#              subzone planning_area             region
# 0      lorong ah soo       hougang  north-east region
# 1  sembawang central     sembawang       north region
# 2      clementi west      clementi        west region
# 3         yuhua west   jurong east        west region
# 4         yuhua west   jurong east        west region

# %%
# Encode "rent_approval_date"
# related to the climate of economy
df['rent_year'] = df.apply(lambda x: x['rent_approval_date'][0:4],axis=1)
df['rent_month'] = df.apply(lambda x: x['rent_approval_date'][5:7],axis=1)
df = df.drop(['rent_approval_date'],axis=1)
df_year = df.pop('rent_year')
df_month = df.pop('rent_month')
df.insert(0,'rent_year',df_year)
df.insert(1,'rent_month',df_month)

df.head()
# Out:
#   rent_year rent_month         town block             street_name flat_type  \
# 0      2023         01      hougang   245       hougang street 22    5-room
# 1      2022         09    sembawang   316         sembawang vista    4-room
# 2      2023         07     clementi   708  Clementi West Street 2    4-room
# 3      2021         08  jurong east   351   Jurong East Street 31    3-room
# 4      2022         03  jurong east   305   jurong east street 32    5-room
#
#        flat_model  floor_area_sqm  lease_commence_date  latitude   longitude  \
# 0        improved           121.0                   39  1.358411  103.891722
# 1         model a           100.0                   23  1.446343  103.820817
# 2  new generation            91.0                   43  1.305719  103.762168
# 3         model a            74.0                   35  1.344832  103.730778
# 4        improved           121.0                   39  1.345437  103.735241
#
#              subzone planning_area             region
# 0      lorong ah soo       hougang  north-east region
# 1  sembawang central     sembawang       north region
# 2      clementi west      clementi        west region
# 3         yuhua west   jurong east        west region
# 4         yuhua west   jurong east        west region

# %%
# Delete "block", "planning_area", "street_name"
# related to the selection of attributes to address

df.drop(["block","planning_area","street_name"], axis=1,inplace=True)

# %%
# Encode "flat_model"
df['flat_model'] = df['flat_type'] + "_" + df['flat_model']
df['flat_model'].unique()
# Clean "flat_model"
df = df.loc[~(df['flat_model']=='5-room_3gen')]
df = df.loc[~(df['flat_model']=='2-room_premium apartment')]
df = df.loc[~(df['flat_model']=='4-room_terrace')]

# %%
# Encode "latitude", "longitude"
# related to the distance of MRT and school
# df_mrt = pd.read_csv('auxiliary-data/sg-mrt-existing-stations.csv')
# df_school = pd.read_csv('auxiliary-data/sg-primary-schools.csv')
# df_shopping = pd.read_csv('auxiliary-data/sg-shopping-malls.csv')
'''
minDist_MRT: Straight line distance to nearest subway station
minDist_school: Straight line distance to nearest primary school
minDist_mall: Straight line distance to the nearest shopping mall
MRT_cnt_500: Number of subway stations within a straight line distance of 500 meters
'''
df.drop(["latitude", "longitude"], axis=1,inplace=True)
gps_processed = pd.read_csv('auxiliary-data/GPS_processed_test.csv')
df.reset_index(inplace=True)
df = df.merge(gps_processed, on='index')
df = df[['index', 'rent_year', 'rent_month', 'town','subzone', 'flat_type', 'flat_model','floor_area_sqm', 'lease_commence_date', 'region',
       'minDist_MRT', 'minDist_school', 'minDist_mall','MRT_cnt_500']]
df.drop('index', axis=1,inplace=True)
df.head()
# Out:
#   rent_year rent_month         town            subzone flat_type  \
# 0      2023         01      hougang      lorong ah soo    5-room
# 1      2022         09    sembawang  sembawang central    4-room
# 2      2023         07     clementi      clementi west    4-room
# 3      2021         08  jurong east         yuhua west    3-room
# 4      2022         03  jurong east         yuhua west    5-room
#
#               flat_model  floor_area_sqm  lease_commence_date  \
# 0        5-room_improved           121.0                   39
# 1         4-room_model a           100.0                   23
# 2  4-room_new generation            91.0                   43
# 3         3-room_model a            74.0                   35
# 4        5-room_improved           121.0                   39
#
#               region  minDist_MRT  minDist_school  minDist_mall  MRT_cnt_500
# 0  north-east region     0.820333        0.149667      0.739403            0
# 1       north region     0.307784        0.143325      0.254920            1
# 2        west region     1.097689        1.040844      0.497670            0
# 3        west region     0.362810        1.075525      1.596397            1
# 4        west region     0.448980        0.714777      1.461487            1

# %%
# Encoding market_index
stock_processed=pd.read_csv('auxiliary-data/stock_processed.csv')
stock_processed['date'] = stock_processed['year'].astype(str) + '-' + stock_processed['month'].astype(str).str.zfill(2)
df['date'] = df['rent_year'].astype(str) + '-' + df['rent_month'].astype(str).str.zfill(2)
df= pd.merge(df, stock_processed[['date', 'market_index']], on='date', how='left')
df=df.drop(columns='date')
df = df[['rent_year', 'rent_month', 'town','subzone', 'flat_type', 'flat_model','floor_area_sqm', 'lease_commence_date', 'region',
       'minDist_MRT', 'minDist_school', 'minDist_mall', 'market_index','MRT_cnt_500']]
df.head()
# Out:
#   rent_year rent_month         town            subzone flat_type  \
# 0      2023         01      hougang      lorong ah soo    5-room
# 1      2022         09    sembawang  sembawang central    4-room
# 2      2023         07     clementi      clementi west    4-room
# 3      2021         08  jurong east         yuhua west    3-room
# 4      2022         03  jurong east         yuhua west    5-room
#
#               flat_model  floor_area_sqm  lease_commence_date  \
# 0        5-room_improved           121.0                   39
# 1         4-room_model a           100.0                   23
# 2  4-room_new generation            91.0                   43
# 3         3-room_model a            74.0                   35
# 4        5-room_improved           121.0                   39
#
#               region  minDist_MRT  minDist_school  minDist_mall  market_index  \
# 0  north-east region     0.820333        0.149667      0.739403          3.52
# 1       north region     0.307784        0.143325      0.254920         -2.84
# 2        west region     1.097689        1.040844      0.497670          5.24
# 3        west region     0.362810        1.075525      1.596397         -3.53
# 4        west region     0.448980        0.714777      1.461487          5.13
#
#    MRT_cnt_500
# 0            0
# 1            1
# 2            0
# 3            1
# 4            1

# %%
# Encoding coe_index
coe_index=pd.read_csv('auxiliary-data/coe_index.csv')
coe_index['date'] = coe_index['year'].astype(str) + '-' + coe_index['month'].astype(str).str.zfill(2)
df['date'] = df['rent_year'].astype(str) + '-' + df['rent_month'].astype(str).str.zfill(2)
df= pd.merge(df, coe_index[['date', 'coe_index']], on='date', how='left')
df=df.drop(columns='date')
df = df[['rent_year', 'rent_month', 'town','subzone', 'flat_type', 'flat_model','floor_area_sqm', 'lease_commence_date', 'region',
       'minDist_MRT', 'minDist_school', 'minDist_mall', 'market_index','coe_index','MRT_cnt_500']]
df.head()
# Out:
#   rent_year rent_month         town            subzone flat_type  \
# 0      2023         01      hougang      lorong ah soo    5-room
# 1      2022         09    sembawang  sembawang central    4-room
# 2      2023         07     clementi      clementi west    4-room
# 3      2021         08  jurong east         yuhua west    3-room
# 4      2022         03  jurong east         yuhua west    5-room
#
#               flat_model  floor_area_sqm  lease_commence_date  \
# 0        5-room_improved           121.0                   39
# 1         4-room_model a           100.0                   23
# 2  4-room_new generation            91.0                   43
# 3         3-room_model a            74.0                   35
# 4        5-room_improved           121.0                   39
#
#               region  minDist_MRT  minDist_school  minDist_mall  market_index  \
# 0  north-east region     0.820333        0.149667      0.739403          3.52
# 1       north region     0.307784        0.143325      0.254920         -2.84
# 2        west region     1.097689        1.040844      0.497670          5.24
# 3        west region     0.362810        1.075525      1.596397         -3.53
# 4        west region     0.448980        0.714777      1.461487          5.13
#
#    coe_index  MRT_cnt_500
# 0    37.1356            0
# 1    37.1669            1
# 2    41.7779            0
# 3    20.8020            1
# 4    31.6204            1

# %%
# Temp Change
df.drop(['flat_type','rent_year','rent_month'], axis=1,inplace=True)

# %%
# # One-hot Encode "town", "region" # Catboost encoder
# df = pd.get_dummies(df)
df.head()
# Out:
#           town            subzone             flat_model  floor_area_sqm  \
# 0      hougang      lorong ah soo        5-room_improved           121.0
# 1    sembawang  sembawang central         4-room_model a           100.0
# 2     clementi      clementi west  4-room_new generation            91.0
# 3  jurong east         yuhua west         3-room_model a            74.0
# 4  jurong east         yuhua west        5-room_improved           121.0
#
#    lease_commence_date             region  minDist_MRT  minDist_school  \
# 0                   39  north-east region     0.820333        0.149667
# 1                   23       north region     0.307784        0.143325
# 2                   43        west region     1.097689        1.040844
# 3                   35        west region     0.362810        1.075525
# 4                   39        west region     0.448980        0.714777
#
#    minDist_mall  market_index  coe_index  MRT_cnt_500
# 0      0.739403          3.52    37.1356            0
# 1      0.254920         -2.84    37.1669            1
# 2      0.497670          5.24    41.7779            0
# 3      1.596397         -3.53    20.8020            1
# 4      1.461487          5.13    31.6204            1

# %%
df.to_csv('cleaned_test.csv', index=False)
